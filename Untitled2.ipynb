# %%
import numpy as np
import pandas as pd
from pyproj import Geod
import datetime
from matplotlib import pyplot as plt
import seaborn as sns
import haversine
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
from math import sin, cos, sqrt, atan2, radians

# %%
train_data = pd.read_csv( "train.csv" )
test_data = pd.read_csv( "test.csv" )

# %%
# Utiliy functions

#Get distance between pairs of lat-lon points
wgs84_geod = Geod(ellps='WGS84')
def get_distance(lat1,lon1,lat2,lon2):
    az12,az21,dist = wgs84_geod.inv(lon1,lat1,lon2,lat2)
    return dist

# %%
def normalize(data):
    return ((data-data.min())/(data.max()-data.min()))


def process_data(data):
    # Calculating distance (m) based on longitude/latituides and adding it in a new column 'dist'
    data['dist'] = get_distance(data['pickup_latitude'].tolist(), data['pickup_longitude'].tolist(),
                                data['dropoff_latitude'].tolist(), data['dropoff_longitude'].tolist())
    
    data['dist'] = data['dist'] / 1000
    data['haversine_distance'] = data.apply(lambda r: haversine.haversine((r['pickup_latitude'],r['pickup_longitude']),
                                                                          (r['dropoff_latitude'], r['dropoff_longitude'])), 
                                                                          axis=1)
    data['manhattan_distance'] = (abs(data.dropoff_longitude - data.pickup_longitude) +
                                  abs(data.dropoff_latitude - data.pickup_latitude))
    
   
    data['log_distance'] = np.log(data['dist'] + 1)
    data['log_haversine_distance'] = np.log(data['haversine_distance'] + 1)
    data['log_manhattan_distance'] = np.log(data.manhattan_distance + 1)
    
    data['sqr_distance'] = data['log_distance']**2
    data['sqr_haversine_distance'] = data['log_haversine_distance']**2
    data['sqr_manhattan_distance'] = data['log_manhattan_distance']**2
    
    data['pickup_datetime'] = pd.to_datetime(data['pickup_datetime'])
    data['pickup_hour'] = data['pickup_datetime'].dt.hour
    data['pickup_weekday'] = data['pickup_datetime'].dt.weekday
    
    data['night_trip'] = [True if x < 7 else False for x in data['pickup_hour']]
    data['rush_hour'] = [True if 9 < x < 20 else False for x in data['pickup_hour']]
    data['weekday'] = [True if x < 5 else False for x in data['pickup_weekday']]

    # Replacing N of store_and_fwd_flag with 0 and Y with 1
    data = data.replace({'N': 0, 'Y': 1})
    
    # Dropping columns no longer required
    data = data.drop(['pickup_latitude','pickup_longitude', 'pickup_datetime', 'pickup_hour', 'pickup_weekday',
                      'dropoff_latitude','dropoff_longitude', 'id'], axis=1)
     
    return data

# %%
# Hypothesis function
def hyp(theta, X):
    return np.dot(X, theta.T)  

# The loss function in our case is the sum of the squared error
def loss_func(theta, X, Y):
    return np.sum(((hyp(theta, X) - Y)**2) / (2 * X.shape[0]))

def get_graident(theta, X, Y):
    derivatives = []
  
    for i in range(0, X.shape[1]):
        derivatives.append(np.sum((hyp(theta, X) - Y) * X[:, i]) / X.shape[0])

    return np.array(derivatives)


def gradient_descent(X, Y, maxniter=20000):
    thetas = np.random.rand(X.shape[1],)
    alpha = 0.01
    costs = []
    
    for i in range(0, maxniter):
        thetas = thetas - (alpha * get_graident(thetas, X, Y))
        costs.append(loss_func(thetas, X, Y))
        
    return thetas, costs

# %%
proc_data = process_data(train_data)
X = normalize(proc_data.drop('trip_duration', axis=1)).values
Y = proc_data['trip_duration'].values

max_iters = 5000
thetas, costs = gradient_descent(X, Y, max_iters)
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.plot(np.arange(0, max_iters), costs)

# %%
pred = hyp(thetas, normalize(process_data(test_data)))
submission = pd.DataFrame({'id':test_data['id'],'trip_duration':pred})
submission.to_csv("kaggle_submission.csv", index=False)

submission['trip_duration'].describe()
# Out:
# count    30000.000000
# mean      1000.708350
# std        541.354030
# min       -233.960534
# 25%        643.775668
# 50%        890.305942
# 75%       1226.909424
# max       4906.161818
# Name: trip_duration, dtype: float64

# %%
submission
# Out:
#               id  trip_duration
# 0      id1430318    1023.032558
# 1      id3276964     664.581150
# 2      id2541342    1177.524484
# 3      id3582288     544.972618
# 4      id2976277     136.176988
# 5      id1856113     781.050062
# 6      id0712136    1134.087134
# 7      id2704634     968.541231
# 8      id2736446     184.479165
# 9      id3267520    1119.214249
# 10     id2060082    1164.460219
# 11     id0668631     916.079913
# 12     id3972794    1177.060816
# 13     id3610505    1632.684001
# 14     id1129765     316.131569
# 15     id0846002     833.391649
# 16     id2738706    1418.721418
# 17     id0077153     322.781563
# 18     id0096075     488.746931
# 19     id1543517    1123.601166
# 20     id1557821     996.820569
# 21     id1453667    1102.861613
# 22     id3968862     595.188079
# 23     id3810234     873.864462
# 24     id2796384    1072.158079
# 25     id3008946     960.028796
# 26     id0025244     359.797807
# 27     id1660873    2844.495420
# 28     id2758688     743.571085
# 29     id2101485    2274.881624
# ...          ...            ...
# 29970  id3405688    1116.898601
# 29971  id0676345    2929.180528
# 29972  id0678858     444.272678
# 29973  id0106618     969.132200
# 29974  id0046333     904.120330
# 29975  id3465989     720.455714
# 29976  id2924748    1521.705742
# 29977  id2657374    1107.713295
# 29978  id2684952     884.216943
# 29979  id0625691     469.846518
# 29980  id2012538     849.630465
# 29981  id1527149    1790.195710
# 29982  id3423389    1246.748304
# 29983  id1491075    1655.983388
# 29984  id1453634     613.214586
# 29985  id3401858    1011.062496
# 29986  id0342521    1408.011350
# 29987  id1704190     948.711576
# 29988  id0879503    1541.761599
# 29989  id0113735    1833.044565
# 29990  id0257806    1079.117019
# 29991  id0787008     880.715547
# 29992  id3011264     532.071084
# 29993  id3369569     888.714577
# 29994  id3029494     648.608852
# 29995  id1173382    1553.672791
# 29996  id2698052     308.742457
# 29997  id0666861    1099.083751
# 29998  id1888498     807.144215
# 29999  id1592665     432.855388
#
# [30000 rows x 2 columns]

# %%
# from scipy import stats
# temp = train_data[train_data.trip_duration <= np.percentile(train_data.trip_duration, 99)]

# fig, ax = plt.subplots(2,2,figsize=(20, 10), sharex=False, sharey = False)
# sns.despine(left=True)
# sns.distplot(temp['trip_duration'].values, label = 'pickup_latitude',color="g",bins = 100, ax=ax[0,0])

# %%
proc_data.columns
# Out:
# Index(['vendor_id', 'passenger_count', 'store_and_fwd_flag', 'trip_duration',
#        'dist', 'haversine_distance', 'manhattan_distance', 'log_distance',
#        'log_haversine_distance', 'log_manhattan_distance', 'night_trip',
#        'rush_hour', 'weekday', 'lat_diff', 'lon_diff'],
#       dtype='object')

# %%
# x_new = pd.DataFrame(X)
proc_data.plot.scatter(x='log_distance', y='trip_duration')

# %%
# proc_data[proc_data['trip_duration'] > 90000]
# proc_data['trip_duration'].describe()
# proc_data = proc_data[proc_data.trip_duration <= np.percentile(proc_data.trip_duration, 99)]
# proc_data['trip_duration'].describe()

# fig, ax = plt.subplots(2,2,figsize=(20, 10), sharex=False, sharey = False)
# sns.despine(left=True)
# sns.distplot(proc_data['trip_duration'].values, label = 'pickup_latitude',color="g",bins = 100, ax=ax[0,0])
